# %% [markdown]
# # Python Learning Handbook

# %% [markdown]
# - Tom Beaulah
# - 12-November-2025

# %% [markdown]
# Style tips for Jupyter
# * Goal	How to do it
# * Add headers	Use #, ##, ### in Markdown cells
# * Add bullet lists	Use - or *
# * Add code snippets	Triple backticks (```)
# * Add section breaks	---
# * Format key terms	**bold** or *italic*
# * Add inline code	`code_here`
# * Show math	Use LaTeX syntax $x^2 + y^2 = z^2$

# %%
# Python Learning Journal

## 2025-11-10 — GroupBy & Value Counts
Today I learned about using `groupby()` with `.value_counts()`:
```python
df.groupby("decade")["category"].value_counts(normalize=True)
# Out:
#   Cell In[1], line 4
#     Today I learned about using `groupby()` with `.value_counts()`:
#           ^
# SyntaxError: invalid syntax
