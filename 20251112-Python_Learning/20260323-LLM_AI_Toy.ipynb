# %%
import os
from google import genai

os.environ["GEMINI_API_KEY"] = "GEMINI_API_KEY"

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# %%
response = client.models.generate_content(
    model="models/gemini-2.5-flash",
    contents="What is the capital of France?"
)
print(response.text)

# %%
for m in client.models.list():
    print(m.name)

# %%
import os
import time
from google import genai

os.environ["GEMINI_API_KEY"] = "YOUR_ACTUAL_KEY_HERE"
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# Upload the video
print("Uploading video...")
video_file = client.files.upload(path="your_video.mp4")  # <-- change this path


# Wait for processing (same pattern as your generate_content, just async)
print("Processing...")
while video_file.state.name == "PROCESSING":
    time.sleep(3)
    video_file = client.files.get(name=video_file.name)

# Your existing pattern, just with video added to contents
response = client.models.generate_content(
    model="models/gemini-2.5-flash",
    contents=[
        video_file,
        "Did a bird visit the fluffball plant in this video? If yes, at what timestamp and what did it do?"
    ]
)
print(response.text)

# Cleanup
client.files.delete(name=video_file.name)
