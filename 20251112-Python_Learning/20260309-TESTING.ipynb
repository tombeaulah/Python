# %%
print({1:2
       })


test_thing = {1,2}

print(test_thing)

print (type(test_thing))



m

# %%
def my_func(value):
    print(value)

try:
    print(my_func({1,2}))
except AssertionError:
    print("Didn't return a list.")

# %%
my_string = "Los Angeles"
my_extract = my_string [ 2 ]
print (my_extract)

# %%
my_string = "Los Angeles"
my_extract = my_string [:6]
print (my_extract)

# %%
print (my_string [0:8:2] )

# %%
my_string = "this sentence will be split up somehow"
print(my_string.split(sep=" ", maxsplit=2)) # split from the left
print(my_string.rsplit(sep=" ", maxsplit=2)) # split from the right

# %%
my_string = "this sentence\rwill be split\nup somehow"

my_string.splitlines()

# %%
my_list = ["this" , "will", "be", "a","string"]

print ("_".join(my_list))

# %%
my_string = " this sentence will be split up somehow.\n"

print (my_string)
print ( my_string.strip() )
print("test")

# %%
str = "Mon Oct 03 06:48:07 +0000 2016"
str1 = "I live near Beverley"


for idx, item in enumerate(str1):
    print (idx, item)

# %%
my_string = "I live near Beverley"

my_string.replace("e")

# %%
my_string = "I live near Beverley"

my_string.replace(" ","_",2)

# %%
custom_string = " but then again, this might work too."

print ( f"This works{custom_string}")

# %%
print ( "The best approach when training for {} in {} is to use the {} method.".format("hiking","mountains","gradual"))
print ( "The best approach when training for {2} in {0} is to use the {1} method.".format("hiking","mountains","gradual"))

# %%
type = "mountians"
activity = "hiking"
method = "gradual"

print ( "The best approach when training for {activity} in {type} is to use the {method} method.".format())

# %%
label1 = "mountians"
label2 = "hiking"
label3 = "gradual"

print ( "The best approach when training for {activity} in {type} is to use the {method} method.".format(activity=label2,type=label1,method=label3))

# %%
my_dict = {"type" : "mountains", "activity" : "hiking", "method" : "gradual"}

print ( "The best approach when training for {data[activity]} in {data[type]} is to use the {data[method]} method.".format(data=my_dict))

# %%
print ("The final {0} was {1:.2f} {2}".format("altitude",  2.564, "km"))

# %%
from datetime import datetime

str1 = "Today's date is {:%Y-%m-%d %H:%M}"

print (str1.format(datetime.now()))

# %%
print(datetime.now()  )

# %%
label1 = "example"
label2 = 4513
string = f"This is a demo of {label1!a} and {label2:e}"

print(string)

# %%
from datetime import datetime
my_date = datetime.now()
print(f"Today’s date is {my_date:%Y %B %d}")

# %%
my_dict = {"type" : "mountains", "activity" : "hiking", "method" : "gradual"}


print (f"The best approach when training for {my_dict[activity]} in {my_dict['type']} is to use the {my_dict['method']} method.")

# %%
print(f"My friend said that \"Python is still widespread\"")

# %%
print ( f"An example of a short sequence of numbers is {[i for i in range(5)]}")
print ( f"An example of a short sequence of numbers is {", ".join(str(i) for i in range(5))}")

# %%
from string import Template 
my_str = Template('The new major trends in AI have variously been called $label1 or $label2')

my_str = my_str.substitute(label1="ground-breaking",label2="hype")

print (my_str)
# Out:
# The new major trends in AI have variously been called ground-breaking or hype

# %%
my_dict = dict(label1="ground-breaking")
my_str = Template('The new major trends in AI have variously been called $label1 or $label2')
my_str = my_str.safe_substitute(my_dict)
print (my_str)
# Out:
# The new major trends in AI have variously been called ground-breaking or $label2

# %%
import re
re.sub(r"data","method" , "The data was superior to the old data")
# Out:
# 'The method was superiod to the old method'

# %%
re.findall(r"User\w","The users with the greatest score were: User8, UserT, User100")
# Out:
# ['User8', 'UserT', 'User1']

# %%
my_string = "I have used logistic regression 1-2 times, and I have used design of experiments 10-30 times."

re.findall(r"\d+-\d+",my_string)
# Out:
# ['1-2', '10-30']

# %%
my_string = "The problem was the names of the groups like: #pinn!e334 and #weewo&^%0"

re.findall(r"#\w+\W+\w+",my_string)
# Out:
# ['#pinn!e334', '#weewo&^%0']

# %%
my_string = "The person that runs the factory might run away if it explodes!!"

re.findall(r"runs?",my_string)
# Out:
# ['runs', 'run']

# %%
my_string = "Examples of finding substring are using dates: 07-12-2026, 8-Apr-25,  28-1-2024"

re.findall(r"\d{1,2}-\w+-\d{2,4}",my_string)
# Out:
# ['07-12-2026', '8-Apr-25', '28-1-2024']

# %%
my_string = "Examples of finding substring are using dates: 07-12-2026, 8-Apr-25,  28-1-2024"

re.findall(r"\d{1,2}-\w+-\d{2,4}",my_string)
# Out:
# None

# %%
my_string = "Examples of finding substring are using dates: 07-12-2026, 8-Apr-25,  28-1-2024"

output = re.match(r"Once\w+",my_string)
print (output)
# Out:
# None

# %%
my_string = "Examples of finding folks.  Folks can be capitlized too!"

output = re.findall(r"folks|Folks",my_string)
print (output)
# Out:
# ['folks', 'Folks']

# %%
my_string = "Examples of finding folks.  Folks can be capitlized too!"

output = re.findall(r"[fF]olks",my_string)
print (output)
# Out:
# ['folks', 'Folks']

# %%
import re
my_string = "Examples of finding folks.  Folks can be capitalized too!"
output = re.findall(r"[a-zA-z]+",my_string)
print (output)
# Out:
# ['Examples', 'of', 'finding', 'folks', 'Folks', 'can', 'be', 'capitalized', 'too']

# %%
my_string = "Examples of finding folks.  Folks can be capitalized too!"
output = re.findall(r"[^bB]+\s?",my_string)
print (output)
# Out:
# ['Examples of finding folks.  Folks can ', 'e capitalized too!']

# %%
my_string = "The problem was the names of the groups like: #pinne334 and #weewo&^%0"
output =re.findall(r"#\w+\W*\d+",my_string)
print (output)
# Out:
# ['#pinne334', '#weewo&^%0']

# %%
import re
my_string = "7 times in 23 weeks, we got groups of 4"
output = re.findall(r"\d+?", my_string)
print (output)
print(len(output))
print(len(my_string))
# Out:
# ['7', '2', '3', '4']
# 4
# 39

# %%
#value={1,2}

@check_list
def my_func(value):
    print(value)



try:
    print(my_func({1,2}))
except AssertionError:
    print("Didn't return a list.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #value={1,2}
# ----> 3 @check_list
#       4 def my_func(value):
#       5     print(value)
#       9 try:
#
# NameError: name 'check_list' is not defined

# %%
import re

my_string = "In psychology there are 5 units, whilst in physics there are 4 days, and in science there are 7 courses."

#str_regex = r"[a-zA-Z]+\s\w+\s\w+\s\d+\s\w+"
str_regex = r"([a-zA-Z]+)\s\w+\s\w+\s(\d+)\s(\w+)"
output =re.findall(str_regex,my_string)
print (output)
# Out:
# [('psychology', '5', 'units'), ('physics', '4', 'days'), ('science', '7', 'courses')]
